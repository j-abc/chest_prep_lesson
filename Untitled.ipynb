# %% [markdown]
# val/class/.jpeg
# 1000 per class
#
#
# HOW MUCH OF THE DATA DO WE HAVE
# -renamed test to val
# -got rid of the 'val' set
# -balanaced classes
# -1000 per class (train), 200 per class (val)
#
# DECIDE WHAT SORT OF SPLITS WE WANT
#
# FORMAT THE DATASET
# 1. figure out how many images we have of each set, in each class
# 2. downsample it and save it to the drive
# 3. upload as a zip to the drive
# 4. in the notebooks, change the actual drive mounting to gdown
#
# PREPARE CONTEXT THROUGHOUT
#
# ---
# STUDENTS SEE THIS:
# ### Classroom Activity | Est Time
# ### Example | Est Time
# ### Exercise (Coding) | Est Time
# ### Exercise (Discussion) | Est Time
#
# INSTRUCTORS SEE THIS:
# # Milestone x.
# ## Activity xx.            | Est Time |
# ## Instructor Lecture:     | Est Time | Pause here to give a lecture
# ### Instructor Notes:      | Est Time | Tips and info on teaching
# ### Classroom Activity:    | Est Time | Instructor demos | Handout Included
# ### Example:               | Est Time | Instructor lecture on code | Handout Included
# ### Exercise (Coding)      | Est Time | Within a student group
# ### Exercise (Discussion)  | Est Time | Within a student group, demo OR discussion
# ---
# ### Classroom Activity | Est Time
# ### Example | Est Time
# ### Exercise (Coding) | Est Time
# ### Exercise (Discussion) | Est Time
#
# ***Section 1***
# # Milestone 1. Understanding pneumonia and x-rays
# ## Instructor Lecture:     | Est Time | Pause here to give a lecture
# ## Activity 1. What are x-rays? | Est Time |
# ### Exercise (Discussion) | Est Time | Within a student group
#
# # Milestone 2. Understanding and manipulating image data
# ## Activity 2a. How computer see images | Est Time |
# ### Exercise (Discussion) | Est Time | Within a student group
# ### Exercise (Coding)     | Est Time | Within a student group
# ## Activity 2b. Manipulating images | Est Time |
# ### Exercise (Coding)     | Est Time | Within a student group
# ### Exercise (Coding)     | Est Time | Within a student group
#
# # Milestone 3. Visualizing & understanding our x-ray data
# ## Activity 3a. What data do we have? | Est Time |
# ### Exercise (Coding)     | Est Time | Within a student group
# ### Exercise (Coding)     | Est Time | Within a student group
# ## Activity 3b. What do our images look like? | Est Time |
# ### Exercise (Coding)     | Est Time | Within a student group
#
# # Milestone 4. A baseline model for predicting pneumonia from x-rays
# ## Activity 4a. Building our model | Est Time |
# ### Exercise (Coding)     | Est Time | Within a student group
# ## Activity 4b. Evaluating our model | Est Time |
# ### Exercise (Coding)     | Est Time | Within a student group
#
# ***Section 2***
# # Milestone 1. Understanding and building Neural Networks
# ## Instructor Lecture: What are Neural Networks and why do we use them?    | Est Time | Pause here to give a lecture
# ## Activity 1a.           | Est Time | Classroom Activity
# ### Classroom Activity: Classroom Neural Network    | Est Time | Instructor demos | Handout Included
# ## Activity 1b. Building Neural Networks | Est Time
# ### Example: Building Networks in Python with Tensorlfow | Est Time | Instructor lecture on code | Handout Included
# ### Exercise (Coding) | Est Time |
# ### Exercise (Coding) | Est Time |
#
# # Milestone 2. Applying Neural Networks to predicting pneumonia
# ## Activity 2a. Framing pneumonia as a machine learning problem
# ### Exercise (Discussion) | Est Time | Within a student group
# ## Activity 2b. Building our custom Neural Network
# ### Exercise (Coding)     | Est Time | Within a student group
# ## Activity 2c. Training our Network
# ### Exercise (Coding)     | Est Time | Within a student group
# ### Exercise (Discussion) | Est Time | Within a student group
#
# # Milestone 3. Exploring Neural Networks that work better with images
# ## (Optional) Instructor Lecture:     | Est Time | Pause here to give a lecture
# ## Activity 3a. Building and training a Convolutional Neural Network
# ### Exercise (Coding)     | Est Time | Within a student group
# ## Activity 3b. Tuning our network to do the best that it can
# ### Exercise (Discussion) | Est Time | Within a student group
# ### Classroom Activity | Est Time
#
# ***Section 3***
# # Milestone 1. Augmenting our data for better training
# ## Activity 1a. What is data augmentation?
# ### Classroom Activity: Classroom Neural Network    | Est Time | Instructor demos | Handout Included
# ## Activity 1b. Applying data augmentation to our x-rays
# ### Exercise (Coding)     | Est Time | Within a student group
#
# # Milestone 2. Applying transfer learning to improve our models
# ## Activity 2a. What is transfer learning?
# ### Classroom Activity: ???  | Est Time | Instructor demos | Handout Included
# ## Activity 2b. Using transfer learning with our x-rays
# ### Exercise (Coding)     | Est Time | Within a student group
#
# # Milestone 3. Evaluating our best models
# ## Activity 3a. How well did our model do?
# ### Exercise (Coding)     | Est Time | Within a student group
# ## Activity 3b. Interpreting sensitivity and specificity
# ### Exercise (Discussion) | Est Time | Within a student group

# %% [markdown]
# ## InstructorNotes: Lecture on Neural Networks Here

# %% [markdown]
# ## View this if you want to follow along with the lecture!

# %% [markdown]
# ### Why try Neural Networks?

# %% [markdown]
# ##
